# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['AI & Data', 'Machine Learning', 'Generative AI', 'Data Engineering', 'AI Ethics', 'Automation', 'Data Science', 'Big Data', 'Blockchain', 'Cloud Computing']
values = [34, 45, 56, 23, 12, 40, 52, 34, 20, 37]

# Create figure and axis objects
fig, ax = plt.subplots(figsize=(10, 6))

# Create the horizontal bar chart
ax.barh(categories, values, color='skyblue')

# Adding labels and title
ax.set_xlabel('Citations/Impact')
ax.set_ylabel('Categories')
ax.set_title('Literature Review of Key Research Topics')

# Auto-adjust layout to ensure labels and title fit without overlap
plt.tight_layout()

# Save the plot as a PNG image with high resolution (300 DPI)
plt.savefig('literature_review_chart.png', dpi=300)

# Show the plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Create a layout for visualization
pos = nx.spring_layout(G, seed=42, k=0.3)  # Adjust 'k' for better spacing

# Plot the graph
plt.figure(figsize=(14, 10))  # Increase figure size for more space
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=8, font_weight="bold", edge_color="gray")

# Adjust layout and title
plt.title("Citation Network for Top 10 Related Papers", fontsize=16)
plt.tight_layout()  # Adjust spacing to avoid overlap

# Show the plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Create a layout for visualization using graphviz_layout for better spacing
pos = nx.nx_agraph.graphviz_layout(G, prog="dot")  # Using Graphviz layout

# Plot the graph
plt.figure(figsize=(14, 10))  # Increase figure size for more space
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=8, font_weight="bold", edge_color="gray")

# Adjust layout and title
plt.title("Citation Network for Top 10 Related Papers", fontsize=16)
plt.tight_layout()  # Automatically adjust layout to avoid overlap

# Show the plot
plt.show()

# %% [raw]
# import networkx as nx
# import matplotlib.pyplot as plt
#
# # Define the relationships between papers (citation edges)
# citation_data = [
#     ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
#     ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
#     ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
#     ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
#     ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
#     ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
#     ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
#     ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
#     ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
#     ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
# ]
#
# # Create a directed graph
# G = nx.DiGraph()
#
# # Add nodes and edges
# for citation in citation_data:
#     G.add_edge(citation[0], citation[1])
#
# # Create a layout for visualization using graphviz_layout for better spacing
# pos = nx.nx_agraph.graphviz_layout(G, prog="dot")  # Using Graphviz layout
#
# # Plot the graph with larger font size
# plt.figure(figsize=(14, 10))  # Increase figure size for more space
# nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=12, font_weight="bold", edge_color="gray")
#
# # Adjust layout and title
# plt.title("Citation Network for Top 10 Related Papers", fontsize=16)
# plt.tight_layout()  # Automatically adjust layout to avoid overlap
# plt.savefig("citation_network_good.png", format="PNG")
#
# # Show the plot
# plt.show()

# %% [raw]
# import networkx as nx
# import matplotlib.pyplot as plt
#
# # Define the relationships between papers (citation edges)
# citation_data = [
#     ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
#     ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
#     ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
#     ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
#     ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
#     ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
#     ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
#     ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
#     ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
#     ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
# ]
#
# # Create a directed graph
# G = nx.DiGraph()
#
# # Add nodes and edges
# for citation in citation_data:
#     G.add_edge(citation[0], citation[1])
#
# # Create a layout for visualization using graphviz_layout for better spacing
# pos = nx.nx_agraph.graphviz_layout(G, prog="dot")  # Using Graphviz layout
#
# # Plot the graph with default font size
# plt.figure(figsize=(14, 10))  # Increase figure size for more space
# nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray")
#
# # Adjust layout and title
# plt.title("Citation Network for Top 10 Related Papers", fontsize=16)
# plt.tight_layout()  # Automatically adjust layout to avoid overlap
#
# # Save the figure to a file
# plt.savefig("citation_network.png", format="PNG")
#
# # Show the plot
# plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Create a layout for visualization using graphviz_layout for better spacing
pos = nx.nx_agraph.graphviz_layout(G, prog="dot")  # Using Graphviz layout

# Plot the graph
plt.figure(figsize=(14, 10))  # Increase figure size for more space
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray")

# Adjust layout and title
plt.title("Citation Network for Top 10 Related Papers", fontsize=16)
plt.tight_layout()  # Automatically adjust layout to avoid overlap

# Save the figure
plt.savefig("citation_network_fixed.png", format="PNG")

# Show the plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Identify the 7 nodes with the highest degree (most connections)
node_degrees = dict(G.degree())
sorted_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)[:7]

# Create a subgraph with these 7 nodes
subgraph_nodes = sorted_nodes
H = G.subgraph(subgraph_nodes)

# Create a layout for visualization using graphviz_layout for better spacing
pos = nx.nx_agraph.graphviz_layout(H, prog="dot")  # Using Graphviz layout

# Plot the graph
plt.figure(figsize=(14, 10))  # Increase figure size for more space
nx.draw(H, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray")

# Adjust layout and title
plt.title("Citation Network for Top 7 Most Interconnected Papers", fontsize=16)
plt.tight_layout()  # Automatically adjust layout to avoid overlap

# Save the figure
plt.savefig("citation_network_top_7.png", format="PNG")

# Show the plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Identify the top 10 nodes with the highest degree (most connections)
node_degrees = dict(G.degree())
sorted_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)

# Select the top 5 and the next 5 most connected papers
top_5_nodes = sorted_nodes[:5]
next_5_nodes = sorted_nodes[5:10]

# Create subgraphs for both groups
subgraph_top_5 = G.subgraph(top_5_nodes)
subgraph_next_5 = G.subgraph(next_5_nodes)

# Create layouts for both groups using graphviz_layout
pos_top_5 = nx.nx_agraph.graphviz_layout(subgraph_top_5, prog="dot")
pos_next_5 = nx.nx_agraph.graphviz_layout(subgraph_next_5, prog="dot")

# Plot the top 5 papers
plt.figure(figsize=(14, 10))  # Increase figure size for more space
nx.draw(subgraph_top_5, pos_top_5, with_labels=True, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray")
plt.title("Citation Network for Top 5 Most Interconnected Papers", fontsize=16)
plt.tight_layout()
plt.savefig("citation_network_top_5.png", format="PNG")
plt.show()

# Plot the next 5 papers
plt.figure(figsize=(14, 10))  # Increase figure size for more space
nx.draw(subgraph_next_5, pos_next_5, with_labels=True, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray")
plt.title("Citation Network for Next 5 Most Interconnected Papers", fontsize=16)
plt.tight_layout()
plt.savefig("citation_network_next_5.png", format="PNG")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import textwrap

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Identify the top 10 nodes with the highest degree (most connections)
node_degrees = dict(G.degree())
sorted_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)

# Select the top 5 and the next 5 most connected papers
top_5_nodes = sorted_nodes[:5]
next_5_nodes = sorted_nodes[5:10]

# Create subgraphs for both groups
subgraph_top_5 = G.subgraph(top_5_nodes)
subgraph_next_5 = G.subgraph(next_5_nodes)

# Create layouts for both groups using graphviz_layout
pos_top_5 = nx.nx_agraph.graphviz_layout(subgraph_top_5, prog="dot")
pos_next_5 = nx.nx_agraph.graphviz_layout(subgraph_next_5, prog="dot")

# Function to wrap the text labels
def wrap_text_labels(pos, labels, width=20):
    wrapped_labels = {}
    for node, label in labels.items():
        wrapped_labels[node] = "\n".join(textwrap.wrap(label, width))
    return wrapped_labels

# Get node labels (with line breaks for wrapping)
top_5_labels = wrap_text_labels(pos_top_5, nx.get_node_attributes(subgraph_top_5, 'name'))
next_5_labels = wrap_text_labels(pos_next_5, nx.get_node_attributes(subgraph_next_5, 'name'))

# Plot the top 5 papers
plt.figure(figsize=(16, 12))  # Increase figure size for more space
nx.draw(subgraph_top_5, pos_top_5, with_labels=True, labels=top_5_labels, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray")
plt.title("Citation Network for Top 5 Most Interconnected Papers", fontsize=16)
plt.tight_layout()  # Automatically adjust layout to avoid overlap
plt.savefig("citation_network_top_5_zoomed.png", format="PNG")
plt.show()

# Plot the next 5 papers
plt.figure(figsize=(16, 12))  # Increase figure size for more space
nx.draw(subgraph_next_5, pos_next_5, with_labels=True, labels=next_5_labels, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray")
plt.title("Citation Network for Next 5 Most Interconnected Papers", fontsize=16)
plt.tight_layout()  # Automatically adjust layout to avoid overlap
plt.savefig("citation_network_next_5_zoomed.png", format="PNG")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import textwrap

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Identify the top 5 nodes with the highest degree (most connections)
node_degrees = dict(G.degree())
sorted_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)

# Select the top 5 and the next 5 most connected papers
top_5_nodes = sorted_nodes[:5]
next_5_nodes = sorted_nodes[5:10]

# Create subgraphs for both groups
subgraph_top_5 = G.subgraph(top_5_nodes)
subgraph_next_5 = G.subgraph(next_5_nodes)

# Create layouts for both groups using graphviz_layout
pos_top_5 = nx.nx_agraph.graphviz_layout(subgraph_top_5, prog="dot")
pos_next_5 = nx.nx_agraph.graphviz_layout(subgraph_next_5, prog="dot")

# Function to wrap the text labels for readability
def wrap_text_labels(pos, labels, width=20):
    wrapped_labels = {}
    for node, label in labels.items():
        wrapped_labels[node] = "\n".join(textwrap.wrap(label, width))
    return wrapped_labels

# Get node labels (with line breaks for wrapping)
top_5_labels = wrap_text_labels(pos_top_5, nx.get_node_attributes(subgraph_top_5, 'name'))
next_5_labels = wrap_text_labels(pos_next_5, nx.get_node_attributes(subgraph_next_5, 'name'))

# Plot the top 5 papers
plt.figure(figsize=(16, 12))  # Increase figure size for more space
nx.draw(subgraph_top_5, pos_top_5, with_labels=True, labels=top_5_labels, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray", alpha=0.7)
plt.title("Citation Network for Top 5 Most Interconnected Papers", fontsize=16)
plt.tight_layout()  # Automatically adjust layout to avoid overlap
plt.savefig("citation_network_top_5_zoomed_fixed.png", format="PNG")
plt.show()

# Plot the next 5 papers
plt.figure(figsize=(16, 12))  # Increase figure size for more space
nx.draw(subgraph_next_5, pos_next_5, with_labels=True, labels=next_5_labels, node_size=3000, node_color="lightblue", font_size=10, font_weight="bold", edge_color="gray", alpha=0.7)
plt.title("Citation Network for Next 5 Most Interconnected Papers", fontsize=16)
plt.tight_layout()  # Automatically adjust layout to avoid overlap
plt.savefig("citation_network_next_5_zoomed_fixed.png", format="PNG")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Define the top 10 papers and the topics
papers = [
    "Generative AI for Smart Data Analytics",
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data",
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age",
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering",
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data",
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?",
    "Data Analysis in the Era of Generative AI",
    "VAE-GAN Based Zero-shot Outlier Detection",
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence",
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"
]

# Define the topics
topics = ["Big Data", "Generative AI", "GPT", "AI Applications"]

# Create a dictionary where each paper has a list of topics it covers
# 1 means the paper covers the topic, 0 means it doesn't
topic_matrix = {
    "Generative AI for Smart Data Analytics": [1, 1, 0, 0],
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data": [1, 1, 0, 1],
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age": [1, 1, 0, 1],
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering": [0, 1, 1, 1],
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data": [0, 1, 0, 1],
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?": [1, 0, 0, 1],
    "Data Analysis in the Era of Generative AI": [0, 1, 0, 1],
    "VAE-GAN Based Zero-shot Outlier Detection": [0, 1, 0, 1],
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence": [0, 1, 0, 1],
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction": [0, 1, 0, 1]
}

# Convert the topic matrix to a DataFrame
df = pd.DataFrame(topic_matrix, index=papers, columns=topics)

# Replace any NaN values with 0 (if there are any)
df = df.fillna(0)

# Ensure the DataFrame contains only numeric (int) values for the heatmap
df = df.astype(int)

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df, annot=True, cmap="YlGnBu", cbar=False, linewidths=0.5, xticklabels=True, yticklabels=True, vmin=0, vmax=1)

# Title and labels
plt.title("Topic Heatmap for Top 10 Papers", fontsize=16)
plt.xlabel("Topics", fontsize=12)
plt.ylabel("Papers", fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Define the papers and topics
papers = [
    "Generative AI for Smart Data Analytics",
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data",
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age",
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering",
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data",
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?",
    "Data Analysis in the Era of Generative AI",
    "VAE-GAN Based Zero-shot Outlier Detection",
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence",
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"
]

# Define the topics
topics = ["Big Data", "Generative AI", "GPT", "GAN (VAE)", "AI Applications"]

# Create a dictionary where each topic contains the number of papers related to it
# The value represents how many papers cover each topic

topic_count = {
    "Big Data": 4,  # Example count for Big Data-related papers
    "Generative AI": 8,  # Example count for Generative AI-related papers
    "GPT": 3,  # Example count for GPT-related papers
    "GAN (VAE)": 2,  # Example count for GAN (VAE)-related papers
    "AI Applications": 5  # Example count for AI Applications-related papers
}

# Convert the topic_count dictionary into a DataFrame for easy plotting
df = pd.DataFrame(list(topic_count.items()), columns=["Topic", "Number of Papers"])

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(df.set_index("Topic").T, annot=True, cmap="YlGnBu", cbar=False, linewidths=0.5, fmt="d", vmin=0)

# Title and labels
plt.title("Heatmap of Topics in Entire Bibliography", fontsize=16)
plt.xlabel("Topics", fontsize=12)
plt.ylabel("Number of Papers", fontsize=12)

import datetime
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Define the papers and the topics each one belongs to
papers_and_topics = {
    "Generative AI for Smart Data Analytics": ["Generative AI", "Big Data"],
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data": ["Big Data", "Generative AI"],
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age": ["Generative AI", "AI Applications"],
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering": ["GPT", "Generative AI"],
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data": ["Generative AI", "AI Applications"],
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?": ["Big Data", "AI Applications"],
    "Data Analysis in the Era of Generative AI": ["Generative AI", "Big Data"],
    "VAE-GAN Based Zero-shot Outlier Detection": ["GAN (VAE)", "Generative AI"],
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence": ["Generative AI", "AI Applications"],
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction": ["Generative AI", "Big Data"]
}

# Define the topics
topics = ["Big Data", "Generative AI", "GPT", "GAN (VAE)", "AI Applications"]

# Create an empty DataFrame to store the co-occurrence matrix
co_occurrence_matrix = pd.DataFrame(np.zeros((5, 5)), columns=topics, index=topics)

# Populate the co-occurrence matrix based on the papers and their topics
for paper, paper_topics in papers_and_topics.items():
    for i, topic1 in enumerate(paper_topics):
        for topic2 in paper_topics[i + 1:]:
            co_occurrence_matrix.loc[topic1, topic2] += 1
            co_occurrence_matrix.loc[topic2, topic1] += 1
        # Count single-topic occurrences
        co_occurrence_matrix.loc[topic1, topic1] += 1

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(co_occurrence_matrix, annot=True, cmap="YlGnBu", cbar=True, fmt="d", linewidths=0.5, vmin=0)

# Title and labels
plt.title("Topic Co-occurrence Matrix of Papers", fontsize=16)
plt.xlabel("Topics", fontsize=12)
plt.ylabel("Topics", fontsize=12)
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Define the papers and the topics each one belongs to
papers_and_topics = {
    "Generative AI for Smart Data Analytics": ["Generative AI", "Big Data"],
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data": ["Big Data", "Generative AI"],
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age": ["Generative AI", "AI Applications"],
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering": ["GPT", "Generative AI"],
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data": ["Generative AI", "AI Applications"],
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?": ["Big Data", "AI Applications"],
    "Data Analysis in the Era of Generative AI": ["Generative AI", "Big Data"],
    "VAE-GAN Based Zero-shot Outlier Detection": ["GAN (VAE)", "Generative AI"],
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence": ["Generative AI", "AI Applications"],
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction": ["Generative AI", "Big Data"]
}

# Define the topics
topics = ["Big Data", "Generative AI", "GPT", "GAN (VAE)", "AI Applications"]

# Create an empty DataFrame to store the co-occurrence matrix
co_occurrence_matrix = pd.DataFrame(np.zeros((5, 5)), columns=topics, index=topics)

# Populate the co-occurrence matrix based on the papers and their topics
for paper, paper_topics in papers_and_topics.items():
    for i, topic1 in enumerate(paper_topics):
        for topic2 in paper_topics[i + 1:]:
            co_occurrence_matrix.loc[topic1, topic2] += 1
            co_occurrence_matrix.loc[topic2, topic1] += 1
        # Count single-topic occurrences
        co_occurrence_matrix.loc[topic1, topic1] += 1

# Ensure all values are integers
co_occurrence_matrix = co_occurrence_matrix.astype(int)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(co_occurrence_matrix, annot=True, cmap="YlGnBu", cbar=True, fmt="d", linewidths=0.5, vmin=0)

# Title and labels
plt.title("Topic Co-occurrence Matrix of Papers", fontsize=16)
plt.xlabel("Topics", fontsize=12)
plt.ylabel("Topics", fontsize=12)
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from collections import Counter

# Define the papers and the topics each one belongs to
papers_and_topics = {
    "Generative AI for Smart Data Analytics": ["Generative AI", "Big Data"],
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data": ["Big Data", "Generative AI"],
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age": ["Generative AI", "AI Applications"],
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering": ["GPT", "Generative AI"],
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data": ["Generative AI", "AI Applications"],
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?": ["Big Data", "AI Applications"],
    "Data Analysis in the Era of Generative AI": ["Generative AI", "Big Data"],
    "VAE-GAN Based Zero-shot Outlier Detection": ["GAN (VAE)", "Generative AI"],
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence": ["Generative AI", "AI Applications"],
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction": ["Generative AI", "Big Data"],
    "Understanding BERT for NLP": ["BERT", "AI Models"],  # Adding a BERT-related paper
    "Recent Advances in AI Models": ["AI Models", "Generative AI"]  # Adding another paper with 'AI Models'
}

# Define the topics
topics = ["Big Data", "Generative AI", "GPT", "GAN (VAE)", "AI Applications", "BERT", "AI Models"]

# Create an empty DataFrame to store the co-occurrence matrix
co_occurrence_matrix = pd.DataFrame(np.zeros((7, 7)), columns=topics, index=topics)

# Populate the co-occurrence matrix based on the papers and their topics
for paper, paper_topics in papers_and_topics.items():
    for i, topic1 in enumerate(paper_topics):
        for topic2 in paper_topics[i + 1:]:
            co_occurrence_matrix.loc[topic1, topic2] += 1
            co_occurrence_matrix.loc[topic2, topic1] += 1
        # Count single-topic occurrences
        co_occurrence_matrix.loc[topic1, topic1] += 1

# Ensure all values are integers
co_occurrence_matrix = co_occurrence_matrix.astype(int)

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(co_occurrence_matrix, annot=True, cmap="YlGnBu", cbar=True, fmt="d", linewidths=0.5, vmin=0)

# Title and labels
plt.title("Topic Co-occurrence Matrix of Papers (Including BERT & AI Models)", fontsize=16)
plt.xlabel("Topics", fontsize=12)
plt.ylabel("Topics", fontsize=12)
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the papers and their topics (including BERT, Big Data, and Synthetic Data)
papers_and_topics = {
    "Generative AI for Smart Data Analytics": ["Generative AI", "Big Data"],
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data": ["Big Data", "Generative AI"],
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age": ["Generative AI", "AI Applications"],
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering": ["GPT", "Generative AI"],
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data": ["Generative AI", "AI Applications"],
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?": ["Big Data", "AI Applications"],
    "Data Analysis in the Era of Generative AI": ["Generative AI", "Big Data"],
    "VAE-GAN Based Zero-shot Outlier Detection": ["GAN (VAE)", "Generative AI"],
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence": ["Generative AI", "AI Applications"],
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction": ["Generative AI", "Big Data"],
    "Understanding BERT for NLP": ["BERT", "AI Models"],  # Adding a BERT-related paper
    "Recent Advances in AI Models": ["AI Models", "Generative AI"],  # Adding another paper with 'AI Models'
    "Synthetic Data Generation for AI Training": ["Synthetic Data", "Big Data"],  # Adding Synthetic Data paper
}

# Define the sets of papers for each topic
bert_papers = {paper for paper, topics in papers_and_topics.items() if "BERT" in topics}
big_data_papers = {paper for paper, topics in papers_and_topics.items() if "Big Data" in topics}
synthetic_data_papers = {paper for paper, topics in papers_and_topics.items() if "Synthetic Data" in topics}

# Calculate the intersections
only_bert = bert_papers - (big_data_papers | synthetic_data_papers)
only_big_data = big_data_papers - (bert_papers | synthetic_data_papers)
only_synthetic_data = synthetic_data_papers - (bert_papers | big_data_papers)
bert_and_big_data = bert_papers & big_data_papers - synthetic_data_papers
bert_and_synthetic_data = bert_papers & synthetic_data_papers - big_data_papers
big_data_and_synthetic_data = big_data_papers & synthetic_data_papers - bert_papers
all_three = bert_papers & big_data_papers & synthetic_data_papers

# Create the Venn diagram
venn = venn3(subsets=(len(only_bert), len(only_big_data), len(bert_and_big_data), len(only_synthetic_data), 
                     len(bert_and_synthetic_data), len(big_data_and_synthetic_data), len(all_three)),
             set_labels=('BERT', 'Big Data', 'Synthetic Data'))

# Label the areas with the paper counts
venn.get_label_by_id('100').set_text(len(only_bert))
venn.get_label_by_id('010').set_text(len(only_big_data))
venn.get_label_by_id('001').set_text(len(only_synthetic_data))
venn.get_label_by_id('110').set_text(len(bert_and_big_data))
venn.get_label_by_id('101').set_text(len(bert_and_synthetic_data))
venn.get_label_by_id('011').set_text(len(big_data_and_synthetic_data))
venn.get_label_by_id('111').set_text(len(all_three))
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot
plt.title("Venn Diagram of Papers by Topics (BERT, Big Data, Synthetic Data)")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# Define sample keywords for Big Data and Generative AI papers
big_data_keywords = {
    "Big Data", "Data Science", "Data Analytics", "Machine Learning", "Data Mining",
    "Cloud Computing", "IoT", "Data Management", "Business Intelligence", "Data Processing"
}
gen_ai_keywords = {
    "Generative AI", "Deep Learning", "Neural Networks", "Artificial Intelligence", "Machine Learning",
    "Natural Language Processing", "GAN", "AI Models", "Data Generation", "AI Applications"
}

# Extract the top 5 keywords from both domains (Big Data and Generative AI)
big_data_top_5 = {"Big Data", "Data Science", "Machine Learning", "Cloud Computing", "Data Management"}
gen_ai_top_5 = {"Generative AI", "Deep Learning", "Neural Networks", "Artificial Intelligence", "Machine Learning"}

# Find the overlap of the top 5 keywords between Big Data and Generative AI
overlap_keywords = big_data_top_5 & gen_ai_top_5

# Create the Venn diagram
venn = venn2(subsets=(len(big_data_top_5 - overlap_keywords), len(gen_ai_top_5 - overlap_keywords), len(overlap_keywords)),
             set_labels=('Big Data Keywords', 'Generative AI Keywords'))

# Label the areas with the number of keywords
venn.get_label_by_id('10').set_text(len(big_data_top_5 - overlap_keywords))  # Only Big Data
venn.get_label_by_id('01').set_text(len(gen_ai_top_5 - overlap_keywords))  # Only Generative AI
venn.get_label_by_id('11').set_text(len(overlap_keywords))  # Both Big Data and Generative AI
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot
plt.title("Venn Diagram: Overlap of Top 5 Keywords in Big Data and Generative AI Papers")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# Define sample keywords for Big Data and Generative AI papers
big_data_keywords = {
    "Big Data", "Data Science", "Data Analytics", "Machine Learning", "Data Mining",
    "Cloud Computing", "IoT", "Data Management", "Business Intelligence", "Data Processing"
}
gen_ai_keywords = {
    "Generative AI", "Deep Learning", "Neural Networks", "Artificial Intelligence", "Machine Learning",
    "Natural Language Processing", "GAN", "AI Models", "Data Generation", "AI Applications"
}

# Extract the top 5 keywords from both domains (Big Data and Generative AI)
big_data_top_5 = {"Big Data", "Data Science", "Machine Learning", "Cloud Computing", "Data Management"}
gen_ai_top_5 = {"Generative AI", "Deep Learning", "Neural Networks", "Artificial Intelligence", "Machine Learning"}

# Find the overlap of the top 5 keywords between Big Data and Generative AI
overlap_keywords = big_data_top_5 & gen_ai_top_5

# Create the Venn diagram
venn = venn2(subsets=(len(big_data_top_5 - overlap_keywords), len(gen_ai_top_5 - overlap_keywords), len(overlap_keywords)),
             set_labels=('Big Data Keywords', 'Generative AI Keywords'))

# Label the areas with the number of keywords
venn.get_label_by_id('10').set_text('\n'.join(big_data_top_5 - overlap_keywords))  # Only Big Data
venn.get_label_by_id('01').set_text('\n'.join(gen_ai_top_5 - overlap_keywords))  # Only Generative AI
venn.get_label_by_id('11').set_text('\n'.join(overlap_keywords))  # Both Big Data and Generative AI
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot with the added labels
plt.title("Venn Diagram: Overlap of Top 5 Keywords in Big Data and Generative AI Papers")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# Define technologies for Big Data and Generative AI
big_data_technologies = {
    "Spark", "Hadoop", "MapReduce", "Flink", "Kafka"
}

gen_ai_technologies = {
    "BERT", "VAE", "GAN", "GPT", "Transformer Networks"
}

# Find the overlap of technologies between Big Data and Generative AI
overlap_technologies = big_data_technologies & gen_ai_technologies

# Create the Venn diagram
venn = venn2(subsets=(len(big_data_technologies - overlap_technologies),
                     len(gen_ai_technologies - overlap_technologies),
                     len(overlap_technologies)),
             set_labels=('Big Data Technologies', 'Generative AI Technologies'))

# Label the areas with the technologies
venn.get_label_by_id('10').set_text('\n'.join(big_data_technologies - overlap_technologies))  # Only Big Data
venn.get_label_by_id('01').set_text('\n'.join(gen_ai_technologies - overlap_technologies))  # Only Generative AI
venn.get_label_by_id('11').set_text('\n'.join(overlap_technologies))  # Both Big Data and Generative AI
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot with the added labels
plt.title("Venn Diagram: Overlap of Technologies in Big Data and Generative AI")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# List of papers and their categories
papers = [
    ("Generative AI for Smart Data Analytics", ["Big Data", "Generative AI", "Data Analytics"]),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", ["Generative AI", "Data Analytics"]),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", ["Generative AI", "Data Engineering"]),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", ["Big Data", "Generative AI"]),
    ("Data Analysis in the Era of Generative AI", ["Big Data", "Generative AI", "Data Analytics"]),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", ["Big Data", "Generative AI"]),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", ["Big Data"]),
    ("Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction", ["Generative AI", "Big Data"]),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", ["Big Data", "Generative AI", "Data Analytics"]),
    ("VAE-GAN Based Zero-shot Outlier Detection", ["Generative AI", "GAN", "VAE"]),
]

# Define technology sets for Big Data and Generative AI
big_data_technologies = {"Spark", "Hadoop", "MapReduce", "Kafka", "Flink", "Big Data", "Data Analytics"}
gen_ai_technologies = {"BERT", "VAE", "GAN", "GPT", "Transformer", "Deep Learning", "Neural Networks"}

# Extract keywords from the papers
big_data_keywords = set()
gen_ai_keywords = set()

# Assign keywords based on the papers
for paper, categories in papers:
    for category in categories:
        if category in big_data_technologies:
            big_data_keywords.add(category)
        if category in gen_ai_technologies:
            gen_ai_keywords.add(category)

# Calculate the overlap
overlap_keywords = big_data_keywords & gen_ai_keywords

# Create a Venn diagram
venn = venn2(subsets=(len(big_data_keywords - overlap_keywords),
                     len(gen_ai_keywords - overlap_keywords),
                     len(overlap_keywords)),
             set_labels=('Big Data Technologies', 'Generative AI Technologies'))

# Label the areas with the keywords (with checks to avoid NoneType errors)
if venn.get_label_by_id('10'):
    venn.get_label_by_id('10').set_text('\n'.join(big_data_keywords - overlap_keywords))  # Only Big Data
if venn.get_label_by_id('01'):
    venn.get_label_by_id('01').set_text('\n'.join(gen_ai_keywords - overlap_keywords))  # Only Generative AI
if venn.get_label_by_id('11'):
    venn.get_label_by_id('11').set_text('\n'.join(overlap_keywords))  # Both Big Data and Generative AI

# Display the plot with the added labels
plt.title("Venn Diagram: Overlap of Technologies in Big Data and Generative AI Papers")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# List of papers and their categories
papers = [
    ("Generative AI for Smart Data Analytics", ["Big Data", "Generative AI", "Data Analytics"]),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", ["Generative AI", "Data Analytics"]),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", ["Generative AI", "Data Engineering"]),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", ["Big Data", "Generative AI"]),
    ("Data Analysis in the Era of Generative AI", ["Big Data", "Generative AI", "Data Analytics"]),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", ["Big Data", "Generative AI"]),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", ["Big Data"]),
    ("Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction", ["Generative AI", "Big Data"]),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", ["Big Data", "Generative AI", "Data Analytics"]),
    ("VAE-GAN Based Zero-shot Outlier Detection", ["Generative AI", "GAN", "VAE"]),
]

# Define technology sets for Big Data and Generative AI
big_data_technologies = {"Spark", "Hadoop", "MapReduce", "Kafka", "Flink", "Big Data", "Data Analytics"}
gen_ai_technologies = {"BERT", "VAE", "GAN", "GPT", "Transformer", "Deep Learning", "Neural Networks"}

# Extract keywords from the papers
big_data_keywords = set()
gen_ai_keywords = set()

# Assign keywords based on the papers
for paper, categories in papers:
    for category in categories:
        if category in big_data_technologies:
            big_data_keywords.add(category)
        if category in gen_ai_technologies:
            gen_ai_keywords.add(category)

# Calculate the overlap
overlap_keywords = big_data_keywords & gen_ai_keywords

# Create a Venn diagram
venn = venn2(subsets=(len(big_data_keywords - overlap_keywords),
                     len(gen_ai_keywords - overlap_keywords),
                     len(overlap_keywords)),
             set_labels=('Big Data Technologies', 'Generative AI Technologies'))

# Label the areas with the keywords (with checks to avoid NoneType errors)
if venn.get_label_by_id('10'):
    venn.get_label_by_id('10').set_text('\n'.join(big_data_keywords - overlap_keywords))  # Only Big Data
if venn.get_label_by_id('01'):
    venn.get_label_by_id('01').set_text('\n'.join(gen_ai_keywords - overlap_keywords))  # Only Generative AI
if venn.get_label_by_id('11'):
    venn.get_label_by_id('11').set_text('\n'.join(overlap_keywords))  # Both Big Data and Generative AI

# Add annotation to the chart to display the list of keywords
plt.text(0.5, 0.9, f"Big Data Technologies: {', '.join(big_data_keywords)}", ha='center', va='center', fontsize=10)
plt.text(0.5, 0.85, f"Generative AI Technologies: {', '.join(gen_ai_keywords)}", ha='center', va='center', fontsize=10)

# Display the plot with the added labels
plt.title("Venn Diagram: Overlap of Technologies in Big Data and Generative AI Papers")
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Define the technologies used in papers (from previous example)
papers_technologies = {
    "Generative AI for Smart Data Analytics": ["Spark", "Hadoop", "MapReduce", "GAN", "VAE"],
    "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data": ["Spark", "Hadoop", "MapReduce"],
    "GPT-4 and Beyond: The Role of Generative AI in Data Engineering": ["GPT", "VAE", "GAN"],
    "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data": ["Spark", "Hadoop", "VAE"],
    "Data Analysis in the Era of Generative AI": ["Spark", "MapReduce", "GAN", "VAE"],
    "Reimagining Enterprise Data Management Using Generative Artificial Intelligence": ["Spark", "MapReduce", "GAN", "VAE", "BERT"],
    "Data-Driven Innovation: Is Big Data the New Source of Business Ideas?": ["MapReduce", "Hadoop"],
    "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction": ["GPT", "GAN", "VAE"],
    "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age": ["BERT", "Hadoop", "GAN", "VAE"],
    "VAE-GAN Based Zero-shot Outlier Detection": ["VAE", "GAN"]
}

# Flatten the list of all technologies used in the papers
all_technologies = [tech for tech_list in papers_technologies.values() for tech in tech_list]

# Count the frequency of each technology
tech_counts = Counter(all_technologies)

# Prepare the data for the bubble chart
tech_names = list(tech_counts.keys())
tech_frequencies = list(tech_counts.values())
tech_sizes = [freq * 100 for freq in tech_frequencies]  # Scale bubble sizes

# Create a bubble chart
plt.figure(figsize=(10, 6))
plt.scatter(tech_names, tech_frequencies, s=tech_sizes, color='skyblue', alpha=0.6, edgecolors="w", linewidth=2)

# Add labels to each bubble
for i, tech in enumerate(tech_names):
    plt.text(tech_names[i], tech_frequencies[i], tech, ha='center', va='center', fontsize=10)

# Customize chart
plt.title("Technologies Used in Papers (Bubble Chart)", fontsize=14)
plt.xlabel("Technologies", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
# Save the plot with a unique filename based on the current date and time
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"chart_{current_time}.png"
plt.savefig(filename)

# Show the plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data"),
    ("Ydata-Profiling: Accelerating Data-Centric AI with High-Quality Data", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Generative AI for Smart Data Analytics", "Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data"),
    ("Data-Driven Innovation: Is Big Data the New Source of Business Ideas?", "GPT-4 and Beyond: The Role of Generative AI in Data Engineering"),
    ("Data Analysis in the Era of Generative AI", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("VAE-GAN Based Zero-shot Outlier Detection", "Leveraging Generative Artificial Intelligence for Financial Market Trading Data Management and Prediction"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Identify the 7 nodes with the highest degree (most connections)
node_degrees = dict(G.degree())
sorted_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)[:7]

# Create a subgraph with these 7 nodes
subgraph_nodes = sorted_nodes
H = G.subgraph(subgraph_nodes)

# Create a layout for visualization using graphviz_layout for better spacing
pos = nx.nx_agraph.graphviz_layout(H, prog="dot")  # Using Graphviz layout

# Increase figure size for more space and make sure it’s large enough for labels
plt.figure(figsize=(16, 12))  # Increased figure size to ensure visibility of labels

# Draw the graph with improved font size and positioning
nx.draw(H, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=12, font_weight="bold", edge_color="gray")

# Adjust layout and title
plt.title("Citation Network for Top 7 Most Interconnected Papers", fontsize=16)

# Automatically adjust the layout to prevent labels from going out of the frame
plt.tight_layout(pad=3.0)  # Increased padding to avoid overlap

# Save the figure
plt.savefig("citation_network_top_7.png", format="PNG")

# Show the plot
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Identify the nodes in the reduced dataset
node_degrees = dict(G.degree())
sorted_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)

# Create a subgraph with these nodes
subgraph_nodes = sorted_nodes
H = G.subgraph(subgraph_nodes)

# Create a layout for visualization using graphviz_layout for better spacing
pos = nx.nx_agraph.graphviz_layout(H, prog="dot")

# Manually adjust positions of nodes to avoid overlapping or going out of the frame
pos["Generative AI for Smart Data Analytics"] = (pos["Generative AI for Smart Data Analytics"][0] - 0.5, pos["Generative AI for Smart Data Analytics"][1] - 0.2)
pos["Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"] = (pos["Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"][0] - 0.3, pos["Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"][1] - 0.1)

# Increase figure size for more space and make sure it’s large enough for labels
plt.figure(figsize=(16, 12))

# Draw the graph with improved font size and positioning
nx.draw(H, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=12, font_weight="bold", edge_color="gray")

# Adjust layout and title
plt.title("Citation Network for Top 5 Most Interconnected Papers", fontsize=16)

# Automatically adjust the layout to prevent labels from going out of the frame
plt.tight_layout(pad=1.0)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1020489/518308867.py:45: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(pad=1.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the relationships between papers (citation edges)
citation_data = [
    ("Generative AI for Smart Data Analytics", "Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"),
    ("GPT-4 and Beyond: The Role of Generative AI in Data Engineering", "Generative AI: Applications, Models, Challenges, Opportunities, and Future Directions"),
    ("Generative AI for Banks: Benchmarks and Algorithms for Synthetic Financial Transaction Data", "Data Analysis in the Era of Generative AI"),
    ("Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age", "Reimagining Enterprise Data Management Using Generative Artificial Intelligence"),
    ("Reimagining Enterprise Data Management Using Generative Artificial Intelligence", "Generative AI for Smart Data Analytics")
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges
for citation in citation_data:
    G.add_edge(citation[0], citation[1])

# Identify the nodes in the reduced dataset
node_degrees = dict(G.degree())
sorted_nodes = sorted(node_degrees, key=node_degrees.get, reverse=True)

# Create a subgraph with these nodes
subgraph_nodes = sorted_nodes
H = G.subgraph(subgraph_nodes)

# Create a layout for visualization using graphviz_layout for better spacing
pos = nx.nx_agraph.graphviz_layout(H, prog="dot")

# Manually adjust positions of nodes to avoid overlapping or going out of the frame
pos["Generative AI for Smart Data Analytics"] = (pos["Generative AI for Smart Data Analytics"][0] - 0.5, pos["Generative AI for Smart Data Analytics"][1] - 0.2)
pos["Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"] = (pos["Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"][0] - 0.3, pos["Exploring the Synergy between Generative AI, Data and Analytics in the Modern Age"][1] - 0.1)

# Increase figure size for more space and make sure it’s large enough for labels
plt.figure(figsize=(16, 12))

# Draw the graph with improved font size and positioning
nx.draw(H, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=12, font_weight="bold", edge_color="gray")

# Adjust layout and title
plt.title("Citation Network for Top 5 Most Interconnected Papers", fontsize=16)

# Automatically adjust the layout to prevent labels from going out of the frame
plt.tight_layout(pad=4.0)

# Save the figure as PNG
output_path = "itation_network_top_5.png"
plt.savefig(output_path, format="PNG")
# Out:
# /tmp/ipykernel_1020489/3430710303.py:45: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(pad=4.0)
