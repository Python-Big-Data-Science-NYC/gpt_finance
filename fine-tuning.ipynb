# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter

# Sample extracted keywords from your bibliography (replace with actual parsed data)
tools = ["LangChain", "LlamaIndex", "NeMo", "Azure AI", "OpenAI", "RAG", "LangSmith"]
platforms = ["Azure", "AWS", "Google Cloud", "Hugging Face", "Local Deployment"]

# Simulated occurrences (replace with actual counts from your references)
data = {
    "LangChain": [5, 3, 2, 4, 1],
    "LlamaIndex": [2, 1, 3, 2, 1],
    "NeMo": [3, 4, 1, 2, 2],
    "Azure AI": [4, 2, 5, 1, 3],
    "OpenAI": [3, 5, 4, 2, 4],
    "RAG": [2, 1, 3, 4, 2],
    "LangSmith": [1, 3, 2, 5, 4]
}

# Convert data to a DataFrame
heatmap_data = pd.DataFrame(data, index=platforms)

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", linewidths=0.5)
plt.xlabel("Tools")
plt.ylabel("Platforms")
plt.title("Heatmap of LLM Tools vs Platforms in References")

from datetime import datetime
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Save the heatmap as a PNG file with the timestamp
filename = f"chart_{timestamp}.png"
plt.savefig(filename, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a new figure
fig, ax = plt.subplots(figsize=(15, 8))

# Define the structure components and their coordinates
components = [
    {"name": "LLM Performance Evaluation", "xy": (0.1, 0.8)},
    {"name": "Fine-Tuning Methods", "xy": (0.3, 0.8)},
    {"name": "LLM Guardrails", "xy": (0.5, 0.8)},
    {"name": "Observability & Monitoring", "xy": (0.7, 0.8)},
    {"name": "Evaluation Tools", "xy": (0.9, 0.8)},
    {"name": "RAG Integration", "xy": (0.2, 0.5)},
    {"name": "LangChain Techniques", "xy": (0.4, 0.5)},
    {"name": "Security Practices", "xy": (0.6, 0.5)},
    {"name": "Best Practices for Fine-Tuning", "xy": (0.8, 0.5)}
]

# Draw components as rectangles with labels
for comp in components:
    x, y = comp['xy']
    rect = patches.Rectangle((x - 0.05, y - 0.03), 0.1, 0.06, linewidth=1.5, edgecolor='blue', facecolor='lightblue')
    ax.add_patch(rect)
    ax.text(x, y, comp['name'], ha='center', va='center', fontsize=9, wrap=True)

# Draw arrows between components for relationships
connections = [
    ((0.1, 0.8), (0.2, 0.5)),  # LLM Performance Evaluation to RAG Integration
    ((0.3, 0.8), (0.4, 0.5)),  # Fine-Tuning Methods to LangChain Techniques
    ((0.5, 0.8), (0.6, 0.5)),  # Guardrails to Security Practices
    ((0.7, 0.8), (0.8, 0.5)),  # Observability to Best Practices
    ((0.9, 0.8), (0.8, 0.5))   # Evaluation Tools to Best Practices
]

for start, end in connections:
    ax.annotate("", xy=end, xytext=start, arrowprops=dict(arrowstyle="->", lw=1.5))

# Set axis properties
ax.axis('off')
plt.title("Architecture Diagram for LLM Evaluation and Fine-Tuning Framework", fontsize=14)
from datetime import datetime
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Save the heatmap as a PNG file with the timestamp
filename = f"chart_{timestamp}.png"
plt.savefig(filename, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a new figure
fig, ax = plt.subplots(figsize=(15, 8))

# Define the structure components and their coordinates
components = [
    {"name": "LLM Performance Evaluation", "xy": (0.1, 0.8)},
    {"name": "Fine-Tuning Methods", "xy": (0.3, 0.8)},
    {"name": "LLM Guardrails", "xy": (0.5, 0.8)},
    {"name": "Observability & Monitoring", "xy": (0.7, 0.8)},
    {"name": "Evaluation Tools", "xy": (0.9, 0.8)},
    {"name": "RAG Integration", "xy": (0.2, 0.5)},
    {"name": "LangChain Techniques", "xy": (0.4, 0.5)},
    {"name": "Security Practices", "xy": (0.6, 0.5)},
    {"name": "Best Practices for Fine-Tuning", "xy": (0.8, 0.5)}
]

# Draw components as rectangles with labels
for comp in components:
    x, y = comp['xy']
    rect = patches.Rectangle((x - 0.05, y - 0.03), 0.1, 0.06, linewidth=1.5, edgecolor='blue', facecolor='lightblue')
    ax.add_patch(rect)
    ax.text(x, y, comp['name'], ha='center', va='center', fontsize=9, wrap=True)

# Draw arrows between components for relationships
connections = [
    ((0.1, 0.8), (0.2, 0.5)),  # LLM Performance Evaluation to RAG Integration
    ((0.3, 0.8), (0.4, 0.5)),  # Fine-Tuning Methods to LangChain Techniques
    ((0.5, 0.8), (0.6, 0.5)),  # Guardrails to Security Practices
    ((0.7, 0.8), (0.8, 0.5)),  # Observability to Best Practices
    ((0.9, 0.8), (0.8, 0.5))   # Evaluation Tools to Best Practices
]

for start, end in connections:
    ax.annotate("", xy=end, xytext=start, arrowprops=dict(arrowstyle="->", lw=1.5))

# Set axis properties
ax.axis('off')
plt.title("Architecture Diagram for LLM Evaluation and Fine-Tuning Framework", fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a new figure
fig, ax = plt.subplots(figsize=(15, 8))

# Define the structure components and their coordinates
components = [
    {"name": "LLM Performance Evaluation", "xy": (0.1, 0.8)},
    {"name": "Fine-Tuning Methods", "xy": (0.3, 0.8)},
    {"name": "LLM Guardrails", "xy": (0.5, 0.8)},
    {"name": "Observability & Monitoring", "xy": (0.7, 0.8)},
    {"name": "Evaluation Tools", "xy": (0.9, 0.8)},
    {"name": "RAG Integration", "xy": (0.2, 0.5)},
    {"name": "LangChain Techniques", "xy": (0.4, 0.5)},
    {"name": "Security Practices", "xy": (0.6, 0.5)},
    {"name": "Best Practices for Fine-Tuning", "xy": (0.8, 0.5)}
]

# Draw components as rectangles with labels
for comp in components:
    x, y = comp['xy']
    rect = patches.Rectangle((x - 0.05, y - 0.03), 0.1, 0.06, linewidth=1.5, edgecolor='blue', facecolor='lightblue')
    ax.add_patch(rect)
    ax.text(x, y, comp['name'], ha='center', va='center', fontsize=9, wrap=True)

# Draw arrows between components for relationships
connections = [
    ((0.1, 0.8), (0.2, 0.5)),  # LLM Performance Evaluation to RAG Integration
    ((0.3, 0.8), (0.4, 0.5)),  # Fine-Tuning Methods to LangChain Techniques
    ((0.5, 0.8), (0.6, 0.5)),  # Guardrails to Security Practices
    ((0.7, 0.8), (0.8, 0.5)),  # Observability to Best Practices
    ((0.9, 0.8), (0.8, 0.5))   # Evaluation Tools to Best Practices
]

for start, end in connections:
    ax.annotate("", xy=end, xytext=start, arrowprops=dict(arrowstyle="->", lw=1.5))

# Set axis properties
ax.axis('off')
plt.title("Flow Chart for LLM Evaluation and Fine-Tuning Framework", fontsize=14)
from datetime import datetime
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Save the heatmap as a PNG file with the timestamp
filename = f"chart_{timestamp}.png"
plt.savefig(filename, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define categories and values for tools mentioned in the bibliography
categories = [
    'Fine-Tuning Tools', 'Security Monitoring', 'Guardrails Integration', 'Evaluation Tools', 'RAG Systems'
]
values = [8, 7, 9, 6, 7]  # Example values based on the perceived importance or frequency

# Radar chart setup
N = len(categories)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
values += values[:1]  # Complete the loop
angles += angles[:1]

# Plot the radar chart
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw={"polar": True})

ax.fill(angles, values, color='lightblue', alpha=0.5)
ax.plot(angles, values, color='blue', linewidth=2)
ax.set_yticks([2, 4, 6, 8, 10])
ax.set_yticklabels(['2', '4', '6', '8', '10'], color='grey', size=10)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)

plt.title("Radar Chart of LLM Tools and Techniques", va='bottom')
from datetime import datetime
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Save the heatmap as a PNG file with the timestamp
filename = f"chart_{timestamp}.png"
plt.savefig(filename, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define categories and values for different platforms from the bibliography
categories = [
    'LangChain', 'Azure AI', 'LlamaIndex', 'NVIDIA NeMo', 'LangSmith'
]
values = [7, 8, 6, 9, 7]  # Example scores representing platform significance or mention frequency

# Radar chart setup
N = len(categories)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
values += values[:1]  # Complete the loop
angles += angles[:1]

# Plot the radar chart
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw={"polar": True})

ax.fill(angles, values, color='lightgreen', alpha=0.5)
ax.plot(angles, values, color='green', linewidth=2)
ax.set_yticks([2, 4, 6, 8, 10])
ax.set_yticklabels(['2', '4', '6', '8', '10'], color='grey', size=10)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)

plt.title("Radar Chart of LLM Platforms", va='bottom')
from datetime import datetime
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Save the heatmap as a PNG file with the timestamp
filename = f"chart_{timestamp}.png"
plt.savefig(filename, bbox_inches='tight')
from datetime import datetime
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Save the heatmap as a PNG file with the timestamp
filename = f"chart_{timestamp}.png"
plt.savefig(filename, bbox_inches='tight')
from datetime import datetime
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Save the heatmap as a PNG file with the timestamp
filename = f"chart_{timestamp}.png"
plt.savefig(filename, bbox_inches='tight')
plt.show()
